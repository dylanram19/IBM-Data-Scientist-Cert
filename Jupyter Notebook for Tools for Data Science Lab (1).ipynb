# %% [markdown]
# # My Jupyter Notebook on IBM Studio

# %% [markdown]
# **Dylan Ramirez**
# **High School Teacher**

# %% [markdown]
# *I am interested in data science in order to gain skills to apply my degree in Economics*

# %% [markdown]
# ### Finding the Product of Three and Six

# %%
3*6
# Out:
# 18

# %% [markdown]
# * Bullet List
# * ~~Strikethrough~~
# * > Quoted Text
